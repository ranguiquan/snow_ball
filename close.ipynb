# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/002027.SZ-2019.csv", index_col=0)
# df['Close']
df.Close.pct_change().plot()
plt.title("daily return")
plt.show()

# %%
df =
